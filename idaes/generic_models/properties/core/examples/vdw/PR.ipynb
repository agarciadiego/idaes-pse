# %% [markdown]
# # Create a dictionary and use Txy diagrams

# %% [markdown]
# ## 1. Introduction
#
# This Jupyter Notebook creates a property package for the generic property package and utilized the Txy diagrams for the generic properties. A dictionary with the neccesary parameters.
#
# ### 1.1 Tutorial objectives
#
# The goals of this tutorial are:
#
# * Create a parameter block directly on a jupyter notebook.
# * Utilize the Generic Property Package, which provides a flexible platform for users to build property packages by calling upon libraries of modular sub-models to build up complex property calculations with the least effort possible.
# * Demonstrate the use of Txy diagrams in the IDAES utilities.

# %% [markdown]
# ## 2. Problem Statement
#
# ### 2.1 Setting up the problem in IDAES
#
# In the next cell, we will be importing the necessary components from Pyomo and IDAES.

# %%
# Import objects from pyomo package
from pyomo.environ import ConcreteModel

# Import idaes logger to set output levels
import idaes.logger as idaeslog

# Import the Generic Parameter Block
from idaes.generic_models.properties.core.generic.generic_property import GenericParameterBlock

# %% [markdown]
# ### 2.2 Importing property sub-libraries
#
# The IDAES generic property package calls upon libraries of modular sub-models to build up complex property calculations with the least effort possible. We have to import these libraries.

# %%
# Import Python libraries
import logging

# Import Pyomo units
from pyomo.environ import units as pyunits

# Import IDAES cores
from idaes.core import LiquidPhase, VaporPhase, Component

from idaes.generic_models.properties.core.state_definitions import FTPx
from idaes.generic_models.properties.core.eos.ideal import Ideal
from idaes.generic_models.properties.core.phase_equil import smooth_VLE
from idaes.generic_models.properties.core.phase_equil.bubble_dew import \
        IdealBubbleDew,LogBubbleDew
from idaes.generic_models.properties.core.eos.ceos import Cubic, CubicType, MixingRuleB
from idaes.generic_models.properties.core.phase_equil.forms import fugacity,log_fugacity

import idaes.generic_models.properties.core.pure.Perrys as Perrys
import idaes.generic_models.properties.core.pure.RPP4 as RPP4

# %% [markdown]
# ### 2.3 Creating a generic property parameter block
#
# The next step is to give all the parameter information required for the sub-libraries. Here we will specify the base units of our model, the bounds on the state properties and the reference conditions of our properties.

# %%
# Add properties parameter blocks to the flowsheet with specifications -- pull from .py file
# from idaes.generic_models.properties.core.examples.BT_VDW import configuration

# %%
#Make configuration from original Dictionary_Txy_diagrams_AG
configuration = {
    # Specifying components
    "components": {
        'benzene': {"type": Component,
                    "elemental_composition": {"C": 6, "H": 6},
                    "dens_mol_liq_comp": Perrys,
                    "enth_mol_liq_comp": Perrys,
                    "enth_mol_ig_comp": RPP4,
                    "pressure_sat_comp": RPP4,
                    "phase_equilibrium_form": {("Vap", "Liq"): fugacity},
                    "parameter_data": {
                        "mw": (78.1136E-3, pyunits.kg/pyunits.mol),  # [1]
                        "pressure_crit": (48.9e5, pyunits.Pa),  # [1]
                        "temperature_crit": (562.2, pyunits.K),  # [1]
                        "omega": 0.212,  # [1]
                        "dens_mol_liq_comp_coeff": {
                            '1': (1.0162, pyunits.kmol*pyunits.m**-3),  # [2] pg. 2-98
                            '2': (0.2655, None),
                            '3': (562.16, pyunits.K),
                            '4': (0.28212, None)},
                        "cp_mol_ig_comp_coeff": {
                            'A': (-3.392E1, pyunits.J/pyunits.mol/pyunits.K),  # [1]
                            'B': (4.739E-1, pyunits.J/pyunits.mol/pyunits.K**2),
                            'C': (-3.017E-4, pyunits.J/pyunits.mol/pyunits.K**3),
                            'D': (7.130E-8, pyunits.J/pyunits.mol/pyunits.K**4)},
                        "cp_mol_liq_comp_coeff": {
                            '1': (1.29E2, pyunits.J/pyunits.kmol/pyunits.K),  # [2]
                            '2': (-1.7E-1, pyunits.J/pyunits.kmol/pyunits.K**2),
                            '3': (6.48E-4, pyunits.J/pyunits.kmol/pyunits.K**3),
                            '4': (0, pyunits.J/pyunits.kmol/pyunits.K**4),
                            '5': (0, pyunits.J/pyunits.kmol/pyunits.K**5)},
                        "enth_mol_form_liq_comp_ref": (
                            49.0e3, pyunits.J/pyunits.mol),  # [3]
                        "enth_mol_form_vap_comp_ref": (
                            82.9e3, pyunits.J/pyunits.mol),  # [3]
                        "pressure_sat_comp_coeff": {'A': (-6.98273, None),  # [1]
                                                    'B': (1.33213, None),
                                                    'C': (-2.62863, None),
                                                    'D': (-3.33399, None)}}},
        'toluene': {"type": Component,
                    "elemental_composition": {"C": 7, "H": 8},
                    "dens_mol_liq_comp": Perrys,
                    "enth_mol_liq_comp": Perrys,
                    "enth_mol_ig_comp": RPP4,
                    "pressure_sat_comp": RPP4,
                    "phase_equilibrium_form": {("Vap", "Liq"): fugacity},
                    "parameter_data": {
                        "mw": (92.1405E-3, pyunits.kg/pyunits.mol),  # [1]
                        "pressure_crit": (41e5, pyunits.Pa),  # [1]
                        "temperature_crit": (591.8, pyunits.K),  # [1]
                        "omega": 0.263,  # [1]
                        "dens_mol_liq_comp_coeff": {
                            '1': (0.8488, pyunits.kmol*pyunits.m**-3),  # [2] pg. 2-98
                            '2': (0.26655, None),
                            '3': (591.8, pyunits.K),
                            '4': (0.2878, None)},
                        "cp_mol_ig_comp_coeff": {
                            'A': (-2.435E1, pyunits.J/pyunits.mol/pyunits.K),  # [1]
                            'B': (5.125E-1, pyunits.J/pyunits.mol/pyunits.K**2),
                            'C': (-2.765E-4, pyunits.J/pyunits.mol/pyunits.K**3),
                            'D': (4.911E-8, pyunits.J/pyunits.mol/pyunits.K**4)},
                        "cp_mol_liq_comp_coeff": {
                            '1': (1.40E2, pyunits.J/pyunits.kmol/pyunits.K),  # [2]
                            '2': (-1.52E-1, pyunits.J/pyunits.kmol/pyunits.K**2),
                            '3': (6.95E-4, pyunits.J/pyunits.kmol/pyunits.K**3),
                            '4': (0, pyunits.J/pyunits.kmol/pyunits.K**4),
                            '5': (0, pyunits.J/pyunits.kmol/pyunits.K**5)},
                        "enth_mol_form_liq_comp_ref": (
                            12.0e3, pyunits.J/pyunits.mol),  # [3]
                        "enth_mol_form_vap_comp_ref": (
                            50.1e3, pyunits.J/pyunits.mol),  # [3]
                        "pressure_sat_comp_coeff": {'A': (-7.28607, None),  # [1]
                                                    'B': (1.38091, None),
                                                    'C': (-2.83433, None),
                                                    'D': (-2.79168, None)}}}},

    # Specifying phases
    "phases":  {'Liq': {"type": LiquidPhase,
                        "equation_of_state": Cubic,
                        "equation_of_state_options": {
                            "type": CubicType.PR,
                            "mixing_rule_b": MixingRuleB.default}},
                'Vap': {"type": VaporPhase,
                        "equation_of_state": Cubic,
                        "equation_of_state_options": {
                            "type": CubicType.PR,
                            "mixing_rule_b": MixingRuleB.default}}},

    # Set base units of measurement
    "base_units": {"time": pyunits.s,
                   "length": pyunits.m,
                   "mass": pyunits.kg,
                   "amount": pyunits.mol,
                   "temperature": pyunits.K},

    # Specifying state definition
    "state_definition": FTPx,
    "state_bounds": {"flow_mol": (0, 100, 1000, pyunits.mol/pyunits.s),
                     "temperature": (273.15, 300, 450, pyunits.K),
                     "pressure": (5e4, 1e5, 1e6, pyunits.Pa)},
    "pressure_ref": (1e5, pyunits.Pa),
    "temperature_ref": (300, pyunits.K),

    # Defining phase equilibria
    "phases_in_equilibrium": [("Vap", "Liq")],
    "phase_equilibrium_state": {("Vap", "Liq"): smooth_VLE},
    "bubble_dew_method": LogBubbleDew,
    "parameter_data": {"PR_kappa": {("benzene", "benzene"): 0.000,
                                    ("benzene", "toluene"): 0.0058,
                                    ("toluene", "benzene"): 0.011,
                                    ("toluene", "toluene"): 0.000}}}

# %% [markdown]
# ### 2.4 Building the model
#
# In the next cell, we will first create a model and attach a the property package.

# %%
# Create the ConcreteModel
model = ConcreteModel()

# Attach the generic property package dictionary to the model
model.params = GenericParameterBlock(default=configuration)
# Out:
# 2022-02-18 15:27:56 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2022-02-18 15:27:56 [WARNING] idaes.generic_models.properties.core.pure.Perrys: DEPRECATED - params.benzene dens_mol_liq_comp_coeff index 'eqn_type' should be specified, defaulting to equation form 1.
# 2022-02-18 15:27:56 [WARNING] idaes.generic_models.properties.core.pure.Perrys: DEPRECATED - params.toluene dens_mol_liq_comp_coeff index 'eqn_type' should be specified, defaulting to equation form 1.

# %% [markdown]
# ## 3.0 Creating Txy diagrams
#
# ### 3.1 Import the TXY_diagram function

# %%
from idaes.core.util.phase_equilibria import Txy_diagram

# %% [markdown]
# ### 3.2 Calling the function

# %%
Txy_diagram(
    model, "benzene", "toluene", 101325, num_points = 5, temperature = 300,  figure_name = None,
    print_legend = True, include_pressure = False, print_level=idaeslog.CRITICAL,
    solver_op={'tol': 1e-6})
# Txy_diagram(
#     model, "benzene", "toluene", 101325, num_points = 25, temperature = 150.15,  figure_name = None,
#     print_legend = True, include_pressure = False, print_level=0,
#     solver_op={'tol': 1e-6})
# Out:
# 2022-02-18 15:27:57 [WARNING] idaes.core.util.scaling: Missing scaling factor for props[1].mole_frac_comp
# 2022-02-18 15:27:57 [WARNING] idaes.core.util.scaling: Missing scaling factor for props[1].mole_frac_comp
# 2022-02-18 15:28:01 [INFO] idaes.init.props: Property package initialization: optimal - Optimal Solution Found.
# Case:  1  Optimal.  benzene x = 0.99
# Case:  2  Optimal.  benzene x = 0.74
# Case:  3  Optimal.  benzene x = 0.50
# Case:  4  Optimal.  benzene x = 0.26
# Case:  5  Optimal.  benzene x = 0.01

# %%
model.display()
# Out:
# Model unknown
#
#   Variables:
#     None
#
#   Objectives:
#     None
#
#   Constraints:
#     None
#
#   Blocks:
#     Block params
#
#       Variables:
#         PR_kappa : PR binary interaction parameters
#             Size=4, Index=params.PR_kappa_index
#             Key                    : Lower : Value  : Upper : Fixed : Stale : Domain
#             ('benzene', 'benzene') :  None :    0.0 :  None :  True :  True :  Reals
#             ('benzene', 'toluene') :  None : 0.0058 :  None :  True :  True :  Reals
#             ('toluene', 'benzene') :  None :  0.011 :  None :  True :  True :  Reals
#             ('toluene', 'toluene') :  None :    0.0 :  None :  True :  True :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         None
#
#       Blocks:
#         Block params.Liq
#
#           Variables:
#             None
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#         Block params.Vap
#
#           Variables:
#             None
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#         Block params.benzene
#
#           Variables:
#             omega : Size=1, Index=None
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : 0.212 :  None :  True :  True :  Reals
#             pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                 Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                 None :  None : 4890000.0 :  None :  True :  True :  Reals
#             temperature_crit : Size=1, Index=None, Units=K
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : 562.2 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_1 : Parameter 1 for liquid phase molar density
#                 Size=1, Index=None, Units=kmol/m**3
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : 1.0162 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_2 : Parameter 2 for liquid phase molar density
#                 Size=1, Index=None
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : 0.2655 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_3 : Parameter 3 for liquid phase molar density
#                 Size=1, Index=None, Units=K
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : 562.16 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_4 : Parameter 4 for liquid phase molar density
#                 Size=1, Index=None
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 0.28212 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_1 : Parameter 1 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K/kmol
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : 129.0 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_2 : Parameter 2 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**2/kmol
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : -0.17 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_3 : Parameter 3 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**3/kmol
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : 0.000648 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_4 : Parameter 4 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**4/kmol
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None :     0 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_5 : Parameter 5 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**5/kmol
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None :     0 :  None :  True :  True :  Reals
#             enth_mol_form_liq_comp_ref : Liquid phase molar heat of formation @ Tref
#                 Size=1, Index=None, Units=kg*m**2/mol/s**2
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 49000.0 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K/mol
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : -33.92 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K**2/mol
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : 0.4739 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K**3/mol
#                 Key  : Lower : Value      : Upper : Fixed : Stale : Domain
#                 None :  None : -0.0003017 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K**4/mol
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : 7.13e-08 :  None :  True :  True :  Reals
#             enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                 Size=1, Index=None, Units=kg*m**2/mol/s**2
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 82900.0 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_A : Coefficient A for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : -6.98273 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_B : Coefficient B for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 1.33213 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_C : Coefficient C for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : -2.62863 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_D : Coefficient D for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : -3.33399 :  None :  True :  True :  Reals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#         Block params.toluene
#
#           Variables:
#             omega : Size=1, Index=None
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : 0.263 :  None :  True :  True :  Reals
#             pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                 Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                 None :  None : 4100000.0 :  None :  True :  True :  Reals
#             temperature_crit : Size=1, Index=None, Units=K
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : 591.8 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_1 : Parameter 1 for liquid phase molar density
#                 Size=1, Index=None, Units=kmol/m**3
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : 0.8488 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_2 : Parameter 2 for liquid phase molar density
#                 Size=1, Index=None
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 0.26655 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_3 : Parameter 3 for liquid phase molar density
#                 Size=1, Index=None, Units=K
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : 591.8 :  None :  True :  True :  Reals
#             dens_mol_liq_comp_coeff_4 : Parameter 4 for liquid phase molar density
#                 Size=1, Index=None
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : 0.2878 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_1 : Parameter 1 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K/kmol
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None : 140.0 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_2 : Parameter 2 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**2/kmol
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : -0.152 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_3 : Parameter 3 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**3/kmol
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : 0.000695 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_4 : Parameter 4 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**4/kmol
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None :     0 :  None :  True :  True :  Reals
#             cp_mol_liq_comp_coeff_5 : Parameter 5 for liquid phase molar heat capacity
#                 Size=1, Index=None, Units=J/K**5/kmol
#                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                 None :  None :     0 :  None :  True :  True :  Reals
#             enth_mol_form_liq_comp_ref : Liquid phase molar heat of formation @ Tref
#                 Size=1, Index=None, Units=kg*m**2/mol/s**2
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 12000.0 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K/mol
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : -24.35 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K**2/mol
#                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                 None :  None : 0.5125 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K**3/mol
#                 Key  : Lower : Value      : Upper : Fixed : Stale : Domain
#                 None :  None : -0.0002765 :  None :  True :  True :  Reals
#             cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                 Size=1, Index=None, Units=J/K**4/mol
#                 Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                 None :  None : 4.911e-08 :  None :  True :  True :  Reals
#             enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                 Size=1, Index=None, Units=kg*m**2/mol/s**2
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 50100.0 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_A : Coefficient A for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : -7.28607 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_B : Coefficient B for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                 None :  None : 1.38091 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_C : Coefficient C for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : -2.83433 :  None :  True :  True :  Reals
#             pressure_sat_comp_coeff_D : Coefficient D for calculating Psat
#                 Size=1, Index=None
#                 Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                 None :  None : -2.79168 :  None :  True :  True :  Reals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#     Block props[1]
#
#       Variables:
#         flow_mol :  Total molar flowrate
#             Size=1, Index=None, Units=mol/s
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :     0 :     1 :  1000 :  True :  True : NonNegativeReals
#         mole_frac_comp : Mixture mole fractions
#             Size=2, Index=params.component_list
#             Key     : Lower : Value                : Upper : Fixed : Stale : Domain
#             benzene : 1e-20 : 0.010000000000000009 : 1.001 :  True :  True :  Reals
#             toluene : 1e-20 :                 0.99 : 1.001 :  True :  True :  Reals
#         pressure : State pressure
#             Size=1, Index=None, Units=kg/m/s**2
#             Key  : Lower   : Value  : Upper     : Fixed : Stale : Domain
#             None : 50000.0 : 101325 : 1000000.0 :  True :  True : NonNegativeReals
#         temperature : State temperature
#             Size=1, Index=None, Units=K
#             Key  : Lower  : Value : Upper : Fixed : Stale : Domain
#             None : 273.15 :   300 :   450 :  True :  True : NonNegativeReals
#         flow_mol_phase : Phase molar flow rates
#             Size=2, Index=params.phase_list, Units=mol/s
#             Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#             Liq :     0 :    0.9999378490087513 :  1000 : False : False : NonNegativeReals
#             Vap :     0 : 5.088165956192896e-05 :  1000 : False : False : NonNegativeReals
#         mole_frac_phase_comp : Phase mole fractions
#             Size=4, Index=params._phase_component_set
#             Key                : Lower : Value                : Upper : Fixed : Stale : Domain
#             ('Liq', 'benzene') : 1e-20 : 0.009999401745474588 : 1.001 : False : False :  Reals
#             ('Liq', 'toluene') : 1e-20 :    0.990011867594293 : 1.001 : False : False :  Reals
#             ('Vap', 'benzene') : 1e-20 :  0.02361829400011634 : 1.001 : False : False :  Reals
#             ('Vap', 'toluene') : 1e-20 :   0.9763929753353398 : 1.001 : False : False :  Reals
#         phase_frac : Phase fractions
#             Size=2, Index=params.phase_list
#             Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#             Liq :     0 :    0.9999377589433965 :  None : False : False :  Reals
#             Vap :     0 : 5.493639334009921e-05 :  None : False : False :  Reals
#         _teq : Temperature for calculating phase equilibrium
#             Size=1, Index=params._pe_pairs, Units=K
#             Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#             ('Vap', 'Liq') :  None : 383.2961200634088 :  None : False : False :  Reals
#         _t1_Vap_Liq : Intermediate temperature for calculating Teq
#             Size=1, Index=None, Units=K
#             Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#             None :  None : 383.29610266297186 :  None : False : False :  Reals
#         temperature_bubble : Bubble point temperature
#             Size=1, Index=params._pe_pairs, Units=K
#             Key            : Lower  : Value              : Upper : Fixed : Stale : Domain
#             ('Vap', 'Liq') : 273.15 : 383.29608487067753 :   450 : False : False :  Reals
#         _mole_frac_tbub : Vapor mole fractions at at bubble temperature
#             Size=2, Index=props[1]._mole_frac_tbub_index
#             Key                       : Lower : Value                : Upper : Fixed : Stale : Domain
#             ('Vap', 'Liq', 'benzene') :     0 : 0.023619695195753427 :  None : False : False :  Reals
#             ('Vap', 'Liq', 'toluene') :     0 :   0.9763803048086314 :  None : False : False :  Reals
#         log_mole_frac_comp : Log of mole fractions of component
#             Size=2, Index=params.component_list
#             Key     : Lower : Value                 : Upper                 : Fixed : Stale : Domain
#             benzene :  -100 :    -4.605170186053927 : 0.0009995003330834232 : False : False :  Reals
#             toluene :  -100 : -0.010050335855860144 : 0.0009995003330834232 : False : False :  Reals
#         log_mole_frac_tbub : Vapor log mole fractions at bubble temperature
#             Size=2, Index=props[1].log_mole_frac_tbub_index
#             Key                       : Lower : Value                : Upper : Fixed : Stale : Domain
#             ('Vap', 'Liq', 'benzene') :  None :  -3.7456743726068984 :     0 : False : False :  Reals
#             ('Vap', 'Liq', 'toluene') :  None : -0.02390311189473657 :     0 : False : False :  Reals
#         temperature_dew : Dew point temperature
#             Size=1, Index=params._pe_pairs, Units=K
#             Key            : Lower  : Value             : Upper : Fixed : Stale : Domain
#             ('Vap', 'Liq') : 273.15 : 383.5963031886581 :   450 : False : False :  Reals
#         _mole_frac_tdew : Liquid mole fractions at at dew temperature
#             Size=2, Index=props[1]._mole_frac_tdew_index
#             Key                       : Lower : Value                : Upper : Fixed : Stale : Domain
#             ('Vap', 'Liq', 'benzene') :     0 : 0.004200909153287755 :  None : False : False :  Reals
#             ('Vap', 'Liq', 'toluene') :     0 :   0.9957990908469215 :  None : False : False :  Reals
#         log_mole_frac_tdew : Liquid log mole fractions at dew temperature
#             Size=2, Index=props[1].log_mole_frac_tdew_index
#             Key                       : Lower : Value                 : Upper : Fixed : Stale : Domain
#             ('Vap', 'Liq', 'benzene') :  None :    -5.472454311949557 :     0 : False : False :  Reals
#             ('Vap', 'Liq', 'toluene') :  None : -0.004209757761886846 :     0 : False : False :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         total_flow_balance : Size=1
#             Key  : Lower : Body                    : Upper
#             None :   0.0 : -1.1269331686825091e-07 :   0.0
#         component_flow_balances : Size=2
#             Key     : Lower : Body                    : Upper
#             benzene :   0.0 :  1.7989261047804406e-07 :   0.0
#             toluene :   0.0 : -1.7870343760328922e-07 :   0.0
#         sum_mole_frac : Size=1
#             Key  : Lower : Body                  : Upper
#             None :   0.0 : 4.311440093829333e-09 :   0.0
#         phase_fraction_constraint : Size=2
#             Key : Lower : Body                   : Upper
#             Liq :   0.0 : -9.006535472977362e-10 :   0.0
#             Vap :   0.0 : 4.0547337781702504e-08 :   0.0
#         _t1_constraint_Vap_Liq : Size=1
#             Key  : Lower : Body                   : Upper
#             None :   0.0 : 1.7492160168330883e-07 :   0.0
#         eq_temperature_bubble : Size=2
#             Key                       : Lower : Body                   : Upper
#             ('Vap', 'Liq', 'benzene') :   0.0 : 1.0214313839185252e-09 :   0.0
#             ('Vap', 'Liq', 'toluene') :   0.0 :  4.431699481000084e-08 :   0.0
#         log_mole_frac_comp_eqn : Size=2
#             Key     : Lower : Body                    : Upper
#             benzene :   0.0 :  -6.583674577731458e-10 :   0.0
#             toluene :   0.0 : -2.3351320876940918e-09 :   0.0
#         log_mole_frac_tbub_eqn : Size=2
#             Key                       : Lower : Body                  : Upper
#             ('Vap', 'Liq', 'benzene') :   0.0 :  4.42745493045571e-09 :   0.0
#             ('Vap', 'Liq', 'toluene') :   0.0 : 4.385936058781681e-09 :   0.0
#         eq_mole_frac_tbub : Size=1
#             Key            : Lower  : Body               : Upper
#             ('Vap', 'Liq') : 1000.0 : 1000.0000000043847 : 1000.0
#         _teq_constraint_Vap_Liq : Size=1
#             Key  : Lower : Body                   : Upper
#             None :   0.0 : 1.7608630969334627e-07 :   0.0
#         eq_temperature_dew : Size=2
#             Key                       : Lower : Body                   : Upper
#             ('Vap', 'Liq', 'benzene') :   0.0 : -6.319389456166391e-12 :   0.0
#             ('Vap', 'Liq', 'toluene') :   0.0 : 5.4200949284322064e-12 :   0.0
#         log_mole_frac_tdew_eqn : Size=2
#             Key                       : Lower : Body                   : Upper
#             ('Vap', 'Liq', 'benzene') :   0.0 : 4.1978486658988956e-10 :   0.0
#             ('Vap', 'Liq', 'toluene') :   0.0 : 2.1027624086400465e-10 :   0.0
#         eq_mole_frac_tdew : Size=1
#             Key            : Lower  : Body               : Upper
#             ('Vap', 'Liq') : 1000.0 : 1000.0000000002094 : 1000.0
#         equilibrium_constraint : Size=2
#             Key                       : Lower : Body                   : Upper
#             ('Vap', 'Liq', 'benzene') :   0.0 :  6.228402253327658e-05 :   0.0
#             ('Vap', 'Liq', 'toluene') :   0.0 : -9.123541531153023e-06 :   0.0

# %% [markdown]
# You can add precision to the plot by increasing the num_points, include a firgure_name in order to save figure in a file or include the pressure in the plot. You can also include more information from the solver by changing the print_level.
